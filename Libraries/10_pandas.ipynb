# %% [markdown]
# # 📘 Pandas
#
# Welcome to the **complete Pandas reference notebook**. This notebook covers:
# - Links to the official documentation
# - Detailed theory and use cases
# - Practical examples for each function
#
# > 📚 Official Docs: [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)
#
# > 📚 Unofficial Docs: [https://www.w3schools.com/python/pandas/](https://www.w3schools.com/python/pandas/)

# %% [markdown]
# | **Function**         | **Purpose**                               | **Example**                                |
# | -------------------- | ----------------------------------------- | ------------------------------------------ |
# | `pd.Series()`        | Create a Series                           | `pd.Series([1, 2, 3])`                     |
# | `pd.DataFrame()`     | Create a DataFrame                        | `pd.DataFrame({'a': [1, 2], 'b': [3, 4]})` |
# | `.head()`            | First n rows                              | `df.head()`                                |
# | `.tail()`            | Last n rows                               | `df.tail()`                                |
# | `.info()`            | Summary of DataFrame                      | `df.info()`                                |
# | `.describe()`        | Statistical summary                       | `df.describe()`                            |
# | `.shape`             | Shape (rows, columns)                     | `df.shape`                                 |
# | `.columns`           | Column names                              | `df.columns`                               |
# | `.index`             | Index values                              | `df.index`                                 |
# | `.dtypes`            | Data types of each column                 | `df.dtypes`                                |
# | `.astype()`          | Convert data type                         | `df['col'].astype(float)`                  |
# | `.sort_values()`     | Sort by column values                     | `df.sort_values('col')`                    |
# | `.sort_index()`      | Sort by index                             | `df.sort_index()`                          |
# | `.rename()`          | Rename columns or index                   | `df.rename(columns={'old': 'new'})`        |
# | `.set_index()`       | Set column as index                       | `df.set_index('col')`                      |
# | `.reset_index()`     | Reset index to default                    | `df.reset_index()`                         |
# | `.drop()`            | Drop rows or columns                      | `df.drop('col', axis=1)`                   |
# | `.loc[]`             | Label-based selection                     | `df.loc[0, 'col']`                         |
# | `.iloc[]`            | Position-based selection                  | `df.iloc[0, 1]`                            |
# | `.isnull()`          | Detect missing values                     | `df.isnull()`                              |
# | `.notnull()`         | Detect non-missing values                 | `df.notnull()`                             |
# | `.fillna()`          | Fill missing values                       | `df.fillna(0)`                             |
# | `.dropna()`          | Drop missing values                       | `df.dropna()`                              |
# | `.duplicated()`      | Detect duplicate rows                     | `df.duplicated()`                          |
# | `.drop_duplicates()` | Remove duplicate rows                     | `df.drop_duplicates()`                     |
# | `.apply()`           | Apply a function to each row/column       | `df['col'].apply(np.sqrt)`                 |
# | `.map()`             | Map values using a dictionary or function | `df['col'].map({'a': 1, 'b': 2})`          |
# | `.groupby()`         | Group data for aggregation                | `df.groupby('col').mean()`                 |
# | `.agg()`             | Multiple aggregation functions            | `df.agg({'col1': 'mean', 'col2': 'sum'})`  |
# | `.merge()`           | Merge DataFrames like SQL join            | `pd.merge(df1, df2, on='key')`             |
# | `.concat()`          | Concatenate along axis                    | `pd.concat([df1, df2])`                    |
# | `.pivot_table()`     | Create a pivot table                      | `df.pivot_table(values='val', index='A')`  |
# | `.melt()`            | Unpivot from wide to long format          | `df.melt(id_vars='id')`                    |
# | `.value_counts()`    | Count unique values                       | `df['col'].value_counts()`                 |
# | `.nunique()`         | Count distinct elements                   | `df['col'].nunique()`                      |
# | `.sample()`          | Random sample of rows                     | `df.sample(n=5)`                           |
# | `.query()`           | Query DataFrame with a string expression  | `df.query('col > 5')`                      |
# | `.corr()`            | Correlation matrix                        | `df.corr()`                                |
# | `.to_csv()`          | Export to CSV file                        | `df.to_csv('file.csv')`                    |
# | `pd.read_csv()`      | Read a CSV file into a DataFrame          | `pd.read_csv('file.csv')`                  |
# | `.to_excel()`        | Export to Excel file                      | `df.to_excel('file.xlsx')`                 |
# | `pd.read_excel()`    | Read Excel file                           | `pd.read_excel('file.xlsx')`               |

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📊 Creating Series and DataFrames
#
# ### 🧠 Theory
#
# - `Series`: A one-dimensional labeled array capable of holding any data type.
# - `DataFrame`: A two-dimensional size-mutable, potentially heterogeneous tabular data.
#
# ### 🛠️ Usage
#
# - `pd.Series(data, index=index)`
# - `pd.DataFrame(data, index=index, columns=columns)`

# %%
# Create a Series
series = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print("Series:\n", series)

# Create a DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
})
print("\nDataFrame:\n", df)
# Out:
# Series:
#  a    10
# b    20
# c    30
# dtype: int64
#
# DataFrame:
#        Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %% [markdown]
# ## 📋 DataFrame Attributes
#
# ### 🧠 Theory
#
# Common attributes used to inspect the DataFrame structure:
#
# | Attribute      | Description                     |
# |----------------|---------------------------------|
# | `df.shape`     | Tuple of (rows, columns)        |
# | `df.size`      | Total number of elements        |
# | `df.columns`   | Column labels                   |
# | `df.index`     | Row index                       |
# | `df.dtypes`    | Data type of each column        |
# | `df.values`    | Numpy representation of values  |

# %%
print("Shape:", df.shape)
print("Size:", df.size)
print("Columns:", df.columns)
print("Index:", df.index)
print("Data Types:\n", df.dtypes)
print("Values:\n", df.values)
# Out:
# Shape: (3, 3)
# Size: 9
# Columns: Index(['Name', 'Age', 'Salary'], dtype='object')
# Index: RangeIndex(start=0, stop=3, step=1)
# Data Types:
#  Name      object
# Age        int64
# Salary     int64
# dtype: object
# Values:
#  [['Alice' 25 50000]
#  ['Bob' 30 60000]
#  ['Charlie' 35 70000]]

# %% [markdown]
# ## 🔍 Indexing and Selection
#
# ### 🧠 Theory
#
# Access elements using:
# - `df['col_name']` for a column
# - `df.loc[]` for label-based selection
# - `df.iloc[]` for integer-based selection
#
# ###  Examples

# %%
# Select column
print(df['Name'])

# Select row by label
print(df.loc[0])

# Select row by index position
print(df.iloc[1])

# %% [markdown]
# ### 🛠️ Project

# %%
# Load a CSV file

data = pd.read_csv("matches.csv")

data.head(6) # To preview first 6 rows
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
data.tail(6) # To preview last 6 rows
# Out:
#       id  season       city        date                  team1  \
# 630  631    2016    Kolkata  2016-05-22  Kolkata Knight Riders
# 631  632    2016     Raipur  2016-05-22       Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24          Gujarat Lions
# 633  634    2016      Delhi  2016-05-25    Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27          Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 630          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# ...

# %%
# To see the shape of data (rows,columns)
data.shape
# Out:
# (636, 18)

# %%
# To see the summary of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
# To see the statistical summary of data (if data in numbers)

data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
# Fetching columns

data[['team1','team2','winner']].head()
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore

# %%
# Fetching rows using iloc[start:stop:step]

#data.iloc[[1,4,5]]

data.iloc[2:15:3]
# Out:
#     id  season       city        date                        team1  \
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                      team2             toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 5      Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 8   Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 11          Mumbai Indians          Mumbai Indians         field  normal
# 14         Kings XI Punjab        Delhi Daredevils           bat  normal
#
#     dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
# Fetching rows & columns using iloc [rows,columns]

data.iloc[0:5,0:5]
# Out:
#    id  season       city        date                        team1
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore

# %%
# Filtering dataframe based on a given condition

mask = data['city'] == "Hyderabad"
data[mask].head()
# Out:
#     id  season       city        date                team1  \
# 0    1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 5    6    2017  Hyderabad  2017-04-09        Gujarat Lions
# 18  19    2017  Hyderabad  2017-04-17  Sunrisers Hyderabad
# 20  21    2017  Hyderabad  2017-04-19  Sunrisers Hyderabad
# 35  36    2017  Hyderabad  2017-04-30  Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# 35        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#     result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0   normal           0  Sunrisers Hyderabad           35               0
# ...

# %%
data[mask].shape
# Out:
# (49, 18)

# %%
mask1 = data['city'] == "Hyderabad"
mask2 = data["date"] > '2010-01-01'
data[mask1 & mask2].head()
data[mask1 & mask2].shape
# Out:
# (42, 18)

# %% [markdown]
# ## Value_counts()
#
# It iterates through all the values in your Series and identifies every distinct (unique) value. For each unique value, it counts how many times it appears in the Series.. It gives you an immediate understanding of the distribution of values in a column. For example, if you have a column for "Gender," value_counts() would quickly tell you how many "Male" and "Female" entries there are

# %%
# value_counts() function is used on categorical data to find frequency

data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting in Pandas

# %%
data['winner'].value_counts().head().plot(kind="barh")
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts().head().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Functions using a Series

# %%
myseries = data['winner'].value_counts()
myseries['Rajasthan Royals']
# Out:
# 63

# %% [markdown]
# ### Sorting

# %%
# Adding using two series using Indexes
# Total matches played by a team in sorted manner

(data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# Sorting dataframe by cities and then dates

data.sort_values(['city','date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# ## Drop Duplicates
#
# It scans the DataFrame (or a specific set of columns) to find rows that are exact copies of other rows. Once identified, it removes these duplicate rows, leaving only unique rows.

# %%
data.drop_duplicates(subset=["city",'season']).shape
# Out:
# (107, 18)

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# Title winner Season wise

data.drop_duplicates(subset='season', keep='last')[["season",'winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians

# %% [markdown]
# ## Groupby()

# %%
season = data.groupby('season')
season

# %%
season.last()['winner']
# Out:
# season
# 2008         Rajasthan Royals
# 2009          Deccan Chargers
# 2010      Chennai Super Kings
# 2011      Chennai Super Kings
# 2012    Kolkata Knight Riders
# 2013           Mumbai Indians
# 2014    Kolkata Knight Riders
# 2015           Mumbai Indians
# 2016      Sunrisers Hyderabad
# 2017           Mumbai Indians
# Name: winner, dtype: object

# %%
# .groups provides a key,value dictionary

season.groups
data.iloc[59,:]
# Out:
# id                                          60
# season                                    2008
# city                                 Bangalore
# date                                2008-04-18
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bangalore
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# result                                  normal
# dl_applied                                   0
# winner                   Kolkata Knight Riders
# win_by_runs                                140
# win_by_wickets                               0
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# umpire3                                    NaN
# Name: 59, dtype: object

# %%
season.get_group(2012)
# Out:
#       id  season       city        date                        team1  \
# 307  308    2012    Chennai  2012-04-04          Chennai Super Kings
# 308  309    2012    Kolkata  2012-04-05        Kolkata Knight Riders
# 309  310    2012     Mumbai  2012-04-06                Pune Warriors
# 310  311    2012     Jaipur  2012-04-06             Rajasthan Royals
# 311  312    2012  Bangalore  2012-04-07  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 376  377    2012     Jaipur  2012-05-20             Rajasthan Royals
# 377  378    2012       Pune  2012-05-22        Kolkata Knight Riders
# 378  379    2012  Bangalore  2012-05-23          Chennai Super Kings
# 379  380    2012    Chennai  2012-05-25          Chennai Super Kings
# 380  381    2012    Chennai  2012-05-27          Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
season[['win_by_runs','win_by_wickets']].mean()
# Out:
#         win_by_runs  win_by_wickets
# season
# 2008      12.155172        3.810345
# 2009      13.403509        3.157895
# 2010      16.266667        3.166667
# 2011      15.041096        3.630137
# 2012      12.972973        3.256757
# 2013      16.328947        2.986842
# 2014      10.733333        3.750000
# 2015      14.406780        2.508475
# 2016      11.266667        4.066667
# 2017      13.355932        3.457627

# %% [markdown]
# ## Project 2

# %%
import pandas as pd

data2 = pd.read_csv("deliveries.csv")

# %%
data2.shape
# Out:
# (150460, 21)

# %%
data2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ### Batsman with most number of runs

# %%
season2 = data2.groupby('batsman')

# %%
season2['batsman_runs'].sum().sort_values(ascending=False).head(6)
# Out:
# batsman
# SK Raina      4548
# V Kohli       4423
# RG Sharma     4207
# G Gambhir     4132
# DA Warner     4014
# RV Uthappa    3778
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### Batsman with most number of 6s

# %%
only6 = (data2[data2['batsman_runs']==6]).groupby('batsman')

# %%
only6["batsman_runs"].value_counts().sort_values(ascending=False).head(5)
# Out:
# batsman    batsman_runs
# CH Gayle   6               266
# SK Raina   6               174
# RG Sharma  6               173
# V Kohli    6               160
# DA Warner  6               160
# Name: count, dtype: int64

# %% [markdown]
# ### 3 Teams againts which DA Warner scored most runs

# %%
mostruns = (data2[data2['batsman'] == 'DA Warner']).groupby('bowling_team')
mostruns['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Kolkata Knight Riders          677
# Kings XI Punjab                668
# Royal Challengers Bangalore    569
# Mumbai Indians                 465
# Chennai Super Kings            338
# Gujarat Lions                  336
# Delhi Daredevils               268
# Rajasthan Royals               231
# Deccan Chargers                226
# Pune Warriors                  118
# Rising Pune Supergiant          83
# Kochi Tuskers Kerala            16
# Rising Pune Supergiants         11
# Sunrisers Hyderabad              8
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### Function for reproducibility

# %%
def runs_scored(name):

    mostruns = (data2[data2['batsman'] == name]).groupby('bowling_team')
    runs = mostruns['batsman_runs'].sum().sort_values(ascending=False)
    return runs

runs_scored("V Kohli")
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### isin()
#
# It takes a Series or DataFrame and a collection of values (like a list, tuple, Series, or set) as input. Returns a boolean Series/DataFrame: For each element in the original Series/DataFrame, it checks if that element exists within the provided collection of values.
#
# - If the element is found in the collection, it returns True.
# - If the element is not found, it returns False.

# %%
# Find most destructive death over batsman in history of IPL
# Strike Rate = (No of runs/ No of balls)/100
# Min batsman 200 balls in over 16-20

# %%
death_overs = data2[data2['over'] > 15]

# %%
batsman_200 = death_overs.groupby('batsman')["batsman_runs"].count()
batsman_200 = batsman_200[batsman_200 > 200]
batsman_list = batsman_200.index.to_list()

# %%
final_df = data2[data2['batsman'].isin(batsman_list)]
final_df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150442       636       2  Royal Challengers Bangalore
# 150443       636       2  Royal Challengers Bangalore
# 150445       636       2  Royal Challengers Bangalore
# 150446       636       2  Royal Challengers Bangalore
# 150448       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball    batsman  non_striker  \
# 0       Royal Challengers Bangalore     1     1  DA Warner     S Dhawan
# 1       Royal Challengers Bangalore     1     2  DA Warner     S Dhawan
# 2       Royal Challengers Bangalore     1     3  DA Warner     S Dhawan
# ...

# %%
runs = final_df.groupby('batsman')['batsman_runs'].sum()
balls = final_df.groupby('batsman')['batsman_runs'].count()
strike_rate = (runs/balls)*100

# %%
strike_rate.sort_values(ascending=False)
# Out:
# batsman
# AB de Villiers      145.129059
# YK Pathan           140.751445
# KA Pollard          140.621266
# DA Warner           138.318401
# DA Miller           137.709251
# JA Morkel           136.938202
# Harbhajan Singh     135.194585
# SK Raina            134.995548
# MS Dhoni            132.835821
# KM Jadhav           130.555556
# JP Faulkner         129.802956
# SPD Smith           128.507127
# RG Sharma           128.497251
# WP Saha             127.727646
# RV Uthappa          127.635135
# V Kohli             126.588437
# Yuvraj Singh        126.390244
# STR Binny           123.747981
# AT Rayudu           123.014257
# KD Karthik          123.008475
# AR Patel            122.672065
# DJ Bravo            122.286822
# JP Duminy           121.970624
# BJ Hodge            121.422376
# AD Mathews          120.868114
# DJ Hussey           120.072661
# LRPL Taylor         120.070838
# RA Jadeja           118.792867
# DPMD Jayawardene    118.791064
# S Dhawan            118.502496
# ...

# %% [markdown]
# ### Merge ()
#
# It takes two pandas DataFrames as input and combines them horizontally (adding columns from one DataFrame to another). The merging typically happens based on one or more "key"/"id"/"index" columns that exist in both DataFrames.

# %%
new = data2.merge(data,left_on='match_id',right_on='id')

# %% [markdown]
# ### reset_index ()
#
# used to reset the index of a DataFrame or Series to the default integer index

# %%
new.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='season',keep='first').sort_values("season")[["season","batsman"]]
# Out:
#     season       batsman
# 10    2008      SE Marsh
# 14    2009     ML Hayden
# 9     2010  SR Tendulkar
# 11    2011      CH Gayle
# 3     2012      CH Gayle
# 2     2013    MEK Hussey
# 6     2014    RV Uthappa
# 17    2015     DA Warner
# 0     2016       V Kohli
# 7     2017     DA Warner

# %% [markdown]
# ## Pivot Table
#
# It transforms data from a list-like format into a table with a new structure.
#
# Key Parameters:
#
#     data: The DataFrame from which to create the pivot table.
#     values: Column(s) to aggregate. If not specified, all numeric columns will be aggregated.
#     index: Column(s) to use for the new DataFrame's index (rows). Can be a single column name or a list of column names.
#     columns: Column(s) to use for the new DataFrame's columns. Can be a single column name or a list of column names.
#     aggfunc: Aggregation function(s) to use. Can be a single function (e.g., 'mean', 'sum', np.mean), a list of functions, or a dictionary mapping columns to functions.
#         Common strings: 'mean', 'sum', 'count', 'min', 'max', 'median', 'first', 'last'.
#         NumPy functions: np.mean, np.sum, np.median, etc.
#     fill_value: Value to replace missing values (NaN) in the pivot table output. Useful for making the table look cleaner or for further calculations.
#     margins: Boolean (default False). If True, adds row and column subtotals/totals (called "margins").
#     dropna: Boolean (default True). If True, don't include columns whose entries are all NaN.
#     margins_name: String (default 'All'). Name of the row/column that will contain the totals when margins=True.

# %%
# Pivot table for batsman hitting 6

mask = data2["batsman_runs"] == 6
six = data2[mask]
six.shape
# Out:
# (6523, 21)

# %%
pt = six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')
pt
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# over
# 1                             5.0              3.0              14.0
# 2                            17.0             21.0              19.0
# 3                            37.0             11.0              30.0
# 4                            34.0             17.0              41.0
# 5                            41.0             27.0              29.0
# 6                            43.0             22.0              27.0
# 7                            22.0             11.0              20.0
# 8                            25.0             13.0              26.0
# 9                            23.0             17.0              32.0
# 10                           23.0             14.0              24.0
# 11                           36.0             15.0              34.0
# 12                           36.0             26.0              38.0
# ...

# %% [markdown]
# ### Heatmap

# %%
import seaborn as sns

sns.heatmap(pt,)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>

# %% [markdown]
# ### Correlation
#
# Correlation describes the strength and direction of a linear relationship between two or more variables. It tells you how closely changes in one variable are associated with changes in another.
# - Positive Correlation: As one variable increases, the other variable also tends to increase. (e.g., more hours studied, higher test scores). The correlation coefficient will be positive (between 0 and +1).
# - Negative Correlation: As one variable increases, the other variable tends to decrease. (e.g., more hours exercising, lower weight). The correlation coefficient will be negative (between 0 and -1).
# - No Correlation (Zero Correlation): There is no consistent linear relationship between the variables.

# %% [markdown]
# ### Rename columns

# %%
data.rename(columns={'city':'place','date':"dom"})
# Out:
#       id  season      place         dom                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ### set_index()
# set_index() function is used to set one or more existing columns as the index of the DataFrame.

# %%
data.set_index(keys='id')
# Out:
#      season       city        date                        team1  \
# id
# 1      2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2      2017       Pune  2017-04-06               Mumbai Indians
# 3      2017     Rajkot  2017-04-07                Gujarat Lions
# 4      2017     Indore  2017-04-08       Rising Pune Supergiant
# 5      2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..      ...        ...         ...                          ...
# 632    2016     Raipur  2016-05-22             Delhi Daredevils
# 633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 635    2016      Delhi  2016-05-27                Gujarat Lions
# 636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# id
# 1    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ### dropna()
# dropna()  function is used to remove missing values (NaN, None, NaT, etc.) from a Series or DataFrame.

# %% [markdown]
# Key Parameters:
#
#     axis: Determines whether to drop rows or columns.
#         0 or 'index' (default): Drops rows containing missing values.
#         1 or 'columns': Drops columns containing missing values.
#     how: Specifies how many missing values are needed to trigger a drop.
#         'any' (default): Drops the row/column if any missing values are present.
#         'all': Drops the row/column only if all values are missing (i.e., the entire row/column is empty).
#     thresh: Requires a minimum number of non-NA values for the row/column to be kept. If thresh=3, a row will only be kept if it has at least 3 non-missing values. This is useful for keeping rows that are mostly complete.
#     subset: Column label or list of column labels. When dropping rows (axis=0), subset specifies which columns to consider for missing values. Only rows with missing values in these specific columns will be dropped.
#     inplace: Boolean (default False). If True, the operation is performed on the original DataFrame/Series and returns None. If False, a new object is returned

# %% [markdown]
# ### fillna()
#
# fillna() function is used to fill (impute) missing values (NaN, None, NaT, etc.) with a specified value or method

# %% [markdown]
# Key Parameters:
#
#     value: The scalar value (e.g., 0, '-', mean_of_column) to use for filling missing values. This is the simplest way.
#     method: A more sophisticated way to fill missing values, often based on adjacent values.
#         'pad' or 'ffill' (forward fill): Fills NaN values with the last valid observation. Useful for time series.
#         'bfill' or 'backfill' (backward fill): Fills NaN values with the next valid observation. Useful for time series.
#     axis: Determines whether to fill along rows (0) or columns (1).
#         0 or 'index' (default): Fills missing values down each column.
#         1 or 'columns': Fills missing values across each row.
#     limit: For method fills, the maximum number of consecutive NaN values to fill.
#     inplace: Boolean (default False). If True, the operation is performed on the original DataFrame/Series and returns None. If False, a new object is returned.
