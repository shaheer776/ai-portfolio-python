# %% [markdown]
# #  Steps for understanding your dataset
# ---
#
# Here are a few steps to get general overview of a dataset by Exploratory data analysis. The example dataset used is the `Titanic dataset`
#
#
# ---
#
# ## 📑 Contents
#
# 1. Univariate Analysis Categorical Data
# 2. Univariate Analysis Numerical Data
# 3. Extract input and output cols
# 4. Train Test split
# 5. Scale the values
# 6. Train the model
# 7. Evaluate the model
# 8. Save the model

# %% [markdown]
# # Getting Data (Titanic dataset)

# %%
import pandas as pd

df = pd.read_csv('dataset.csv') # To read any CSV file
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Univariate Analysis
#
# ## 1. Categorical Data
#
# ### a. Countplot

# %%
import seaborn as sns

sns.countplot(df, x="Survived")
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(df, x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### b. Pie chart

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')  # Shows percentage of people who could and couldn't survived
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')  # Shows percentage of people in various classes
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')  # Shows percentage of gender of people aboard titanic
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2. Numerical Data
#
# ### a. Histogram

# %%
import matplotlib.pyplot as plt

plt.hist([df['Age']]) # Histogram shows the distribution of data
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### b. Distplot

# %%
sns.distplot(df['Age']) # The line is the Probability density function
# Out:
# C:\Users\shahe\AppData\Local\Temp\ipykernel_18828\3899470369.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age']) # The line is the Probability density function
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### c. Boxplot

# %%
sns.boxplot(df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)
