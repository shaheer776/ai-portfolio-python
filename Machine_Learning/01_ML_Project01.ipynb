# %% [markdown]
# # 🧠 Machine Learning Toy Dataset Project
# ---
#
# Based on a data of students' IQ and cgpa, predict whether they will get a placement or not. Use logistic regression.
#
#
# ---
#
# ## 📑 Contents
#
# 1. Getting Data
# 2. Preprocess + EDA + Feature Selection
# 3. Extract input and output cols
# 4. Train Test split
# 5. Scale the values
# 6. Train the model
# 7. Evaluate the model
# 8. Save the model

# %% [markdown]
# # Steps
#
# - Preprocess + EDA + Feature Selection
# - Extract input and output cols
# - Scale the values
# - Train Test split
# - Train the model
# - Evaluate the model
# - Save the model

# %% [markdown]
# # 1. Getting Data

# %%
import numpy
import pandas as pd

# %%
df = pd.read_csv('./placement.csv')
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %% [markdown]
# # 2. Preprocess
#
# Removing first column of data

# %%
df = df.iloc[:,1:]
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.shape
# Out:
# (100, 3)

# %% [markdown]
# # 2.1 EDA

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# # 3. Extract input and output cols

# %%
X = df.iloc[:,0:2]
y = df.iloc[:, -1]
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# # 4. Train Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 88   4.4  149.0
# 14   6.1  103.0
# 43   6.8  141.0
# 78   6.1   81.0
# 41   5.4  114.0
# ..   ...    ...
# 56   6.1   65.0
# 65   8.1  166.0
# 11   6.9  138.0
# 0    6.8  123.0
# 48   6.6  138.0
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 20    1
# 76    0
# 75    0
# 28    0
# 77    1
# 25    0
# 5     1
# 38    1
# 47    0
# 60    1
# Name: placement, dtype: int64

# %% [markdown]
# # 5. Scale the Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-1.38042213,  0.63284732],
#        [ 0.09036189, -0.53940677],
#        [ 0.69597884,  0.42897704],
#        [ 0.09036189, -1.10005003],
#        [-0.51525506, -0.25908514],
#        [ 0.00384519,  0.63284732],
#        [-0.94783859, -1.60972573],
#        [-0.77480518, -1.4823068 ],
#        [ 0.43642872, -2.22133656],
#        [ 2.16676286, -0.10618244],
#        [-0.77480518,  1.3209095 ],
#        [ 0.69597884, -0.87069597],
#        [ 0.86901226,  1.90703655],
#        [-1.72648896, -0.61585813],
#        [ 0.86901226,  0.37800947],
#        [ 1.12856238,  0.3270419 ],
#        [ 1.73417933, -1.1510176 ],
#        [ 0.26339531, -0.53940677],
#        [-0.68828847,  0.19962298],
#        [-0.51525506, -0.43747164],
#        [ 0.26339531,  0.09768784],
#        [-0.77480518,  0.09768784],
#        [-1.20738871,  0.55639596],
#        [ 0.00384519, -0.0042473 ],
#        [ 0.69597884, -0.31005271],
#        [-0.86132188, -0.15715   ],
#        [ 0.00384519, -2.01746628],
#        [-0.25570493,  1.14252301],
#        [ 0.60946214,  0.76026624],
#        [-0.86132188, -1.55875816],
#        [ 1.3881125 , -0.89617976],
#        [-1.0343553 ,  0.9896203 ],
#        [ 1.12856238, -0.20811757],
#        [-1.12087201, -0.94714733],
#        [-0.16918823,  1.06607165],
#        [-0.94783859,  0.25059055],
#        [-1.12087201, -0.08069865],
#        [-1.81300566, -0.38650407],
#        [ 1.30159579,  0.14865541],
#        [ 1.82069604,  0.63284732],
#        [ 0.00384519, -0.56489056],
#        [-1.38042213, -2.09391763],
#        [-0.94783859,  1.83058519],
#        [-0.68828847, -0.36102028],
#        [ 1.30159579, -1.60972573],
#        [-1.72648896, -1.25295274],
#        [ 0.60946214,  1.47381221],
#        [-0.94783859, -0.10618244],
#        [-0.16918823,  0.45446082],
#        [ 0.43642872,  0.14865541],
#        [ 0.86901226, -0.31005271],
#        [ 0.78249555, -0.71779327],
#        [-1.0343553 , -0.31005271],
#        [-2.33210591,  1.49929599],
#        [ 0.09036189,  0.19962298],
#        [ 1.21507909,  0.19962298],
#        [-1.0343553 ,  0.42897704],
#        [-0.25570493,  0.47994461],
#        [ 1.99372945,  1.11703922],
#        [ 0.95552897,  0.68381489],
#        [-0.51525506,  0.27607433],
#        [ 0.86901226,  1.29542572],
#        [-0.68828847,  2.54413116],
#        [ 0.1768786 , -0.28456893],
#        [-0.08267152, -0.46295542],
#        [ 1.30159579,  0.86220138],
#        [ 1.56114592, -0.25908514],
#        [-0.51525506,  0.37800947],
#        [ 0.86901226, -1.53327437],
#        [ 1.3881125 ,  0.09768784],
#        [ 0.00384519, -1.4823068 ],
#        [ 1.12856238, -0.97263111],
#        [-0.60177176, -0.25908514],
#        [-2.15907249,  2.77348522],
#        [ 0.09036189,  0.81123381],
#        [-0.60177176, -0.08069865],
#        [ 0.43642872, -0.87069597],
#        [-0.25570493,  0.40349326],
#        [ 0.26339531,  0.07220406],
#        [ 0.34991202,  0.42897704],
#        [-1.12087201, -1.83907979],
#        [ 0.34991202, -0.20811757],
#        [-1.46693883,  1.93252033],
#        [-0.25570493,  0.19962298],
#        [-0.94783859,  0.68381489],
#        [ 0.09036189, -1.50779059],
#        [ 1.82069604,  1.06607165],
#        [ 0.78249555,  0.35252569],
#        [ 0.69597884, -0.02973108],
#        [ 0.52294543,  0.35252569]])

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 0.52294543, -0.10618244],
#        [-0.94783859,  0.78575002],
#        [-1.0343553 ,  1.14252301],
#        [-0.68828847, -0.87069597],
#        [ 1.12856238, -1.89004736],
#        [-0.86132188, -0.84521219],
#        [ 0.95552897, -1.94101492],
#        [ 0.43642872,  0.91316895],
#        [-0.68828847,  0.93865273],
#        [ 0.78249555,  0.37800947]])

# %% [markdown]
# # 6. Train the model

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

# %%
# Model Training

clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 20    1
# 76    0
# 75    0
# 28    0
# 77    1
# 25    0
# 5     1
# 38    1
# 47    0
# 60    1
# Name: placement, dtype: int64

# %% [markdown]
# # 7. Evaluate the Model

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# # 8. Save Model

# %%
import pickle

pickle.dump(clf, open('model.pkl', 'wb'))
